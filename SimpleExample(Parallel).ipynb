# %%
#%help()

# %%
#%connect(host=trydev.activeeon.com,port=8080,login=MY_LOGIN,password=MY_PASSWORD)

# %% [markdown]
# ### Imports

# %%
#%import()
import os

# %% [markdown]
# ### Initialization

# %%
#%task(name=init,export=[a,b])
pid = os.getpid()
print('Process ' + str(pid) + ': Initialization phase')
a = 2
b = 3

# %% [markdown]
# ### Calculation

# %%
#%task(name=calc1,import=[a,b],dep=[init])
pid = os.getpid()
print('Process ' + str(pid) + ': Calculation phase')
print('Recieved a = ' + str(a))
print('Recieved b = ' + str(b))
c = a + b
print('Sum = ' + str(c))

# %%
#%task(name=calc2,import=[a,b],dep=[init])
pid = os.getpid()
print('Process ' + str(pid) + ': Calculation phase')
print('Recieved a = ' + str(a))
print('Recieved b = ' + str(b))
c = a - b
print('Min = ' + str(c))

# %%
#%draw_job()

# %%
#%show_scheduling_portal()

# %%
#%submit_job()

# %%
#%print_job_output(job_id=9)
